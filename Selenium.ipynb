# %% [markdown]
# <a href="https://colab.research.google.com/github/Rohanpeerla/Software-Engineering-Lab-/blob/main/Selenium.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !wget -q -O chromedriver.zip https://edgedl.me.gvt1.com/edgedl/chrome/chrome-for-testing/134.0.6998.165/linux64/chromedriver-linux64.zip
# !unzip chromedriver.zip
# !chmod +x chromedriver-linux64/chromedriver
# !mv chromedriver-linux64/chromedriver /usr/bin/chromedriver
# Out:
# Archive:  chromedriver.zip
# replace chromedriver-linux64/LICENSE.chromedriver? [y]es, [n]o, [A]ll, [N]one, [r]ename: chmod: cannot access 'chromedriver-linux64/chromedriver': No such file or directory
# mv: cannot stat 'chromedriver-linux64/chromedriver': No such file or directory

# %%
# !pip uninstall -y selenium
# !pip install selenium==4.9.1
# Out:
# Found existing installation: selenium 4.9.1
# Uninstalling selenium-4.9.1:
#   Successfully uninstalled selenium-4.9.1
# ...
#   Using cached selenium-4.9.1-py3-none-any.whl.metadata (7.2 kB)
# ...
# Using cached selenium-4.9.1-py3-none-any.whl (6.6 MB)
# ...
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# msedge-selenium-tools 3.141.4 requires selenium==3.141, but you have selenium 4.9.1 which is incompatible.
# ...

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.chrome.options import Options
chrome_options = Options()
chrome_options.add_argument("--headless")
chrome_options.add_argument("--no-sandbox")
chrome_options.add_argument("--disable-dev-shm-usage")
service = Service("/usr/bin/chromedriver")
driver = webdriver.Chrome(service=service, options=chrome_options)
driver.get("https://www.google.com")
print("Page Title:", driver.title)
driver.quit()
# Out:
# Page Title: Google
